# %% [markdown]
# ## What is MCP?
#
# MCP: Model Context Protocol
#
# MCP server acts as a mediator between the agent & the tools

# %% [markdown]
# ![mcp_architecture.png](attachment:mcp_architecture.png)

# %% [markdown]
# - MCP Server architecture creates tools isolated from each other & the entire communication is done by the server & the agent(client). Hence if any tool fails, only the corresponding functionality will get affected instead of resulting entire system crash.
#
# - We will start with very basic examples and gradually will move to more complex architectures
