# %%
x = 5
y = 7
z = x + y
print(z)
# Out:
# 12

# %%
a = 10
b = 20
c = a + b

# %%
y = 20

# %%
x += 5
y += 10
print(x)
print(y)
# Out:
# 20
# 50

# %% [markdown]
# # Introduction to Google Colab
#
# **How to make fonts bold?** <br>
# Line Break in Colab
#
# *Making fonts italic*
#
# ***Bold & Italic***
#
# My List:
# 1. My 1st list item
# 2. My 2nd list item
#
# Your favourite movies:
# * Your 1st movie
# * Your 2nd movie
#
# <h1>Python for San Diego</h1> Hey let me sit beside you
#
# <ol>
#   <li>1st thing first</li>
#   <li>2nd thing second</li>
# </ol>
#
# <ul>
#   <li>I am block</li>
#   <li>I will occupy all available space</li>
# </ul>

# %% [markdown]
# ![mountain-6190523_1280.jpg](data:image/jpeg;base64,...)

# %%
p = 3
q = 7
r = p + q
r
y
# Out:
# 30
